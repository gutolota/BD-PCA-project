# %%
import pandas as pd
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv', sep=',')

# %%
k_model = KMeans(n_clusters=2, max_iter=10000000000)
k_model.fit(df)
data = k_model.predict(df)
data_df = df.copy()
data_df['cluster'] = data

# %%
data_df
# Out:
#                       0           1  cluster
#  128.491894 -200.665511 -215.443542        1
# -58.873613   -47.301358 -188.783995        0
# -53.000000  -195.205521 -158.562253        1
#  125.000000 -198.919820 -158.000000        1
# -52.912969  -213.518586 -157.521009        1
# ...                 ...         ...      ...
#  125.041991 -206.033961 -133.873972        1
# -59.794733  -193.742331 -187.847783        1
# -45.376385   -24.084555 -191.596280        0
#  118.965270  -55.578707 -178.503248        0
#  98.385905  -197.442788 -199.772232        1
#
# [100000 rows x 3 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 100000 entries, 128.4918944585121 to 98.38590472767484
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   0        100000 non-null  float64
#  1   1        100000 non-null  float64
#  2   cluster  100000 non-null  int32
# dtypes: float64(2), int32(1)
# memory usage: 2.7 MB

# %%
plt.figure(figsize=(11, 8))
sns.scatterplot(data=data_df, x='0', y='1', hue='cluster')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(['A', 'B'], title='cluster')
